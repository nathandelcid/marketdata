# %% [markdown]
# $$\mathbf{x}^{(i)}=\begin{bmatrix}\mathcal{C}_{p}^{(i)}\\
# \mathcal{V}^{(i)}\\
# \text{QAV}^{(i)}\\
# \text{NOT}^{(i)}\\
# \text{TBBV}^{(i)}\\
# \text{RSI}_{14}^{(i)}\\
# \text{RSI}_{30}^{(i)}\\
# \text{RSI}_{200}^{(i)}\\
# \text{MOM}_{10}^{(i)}\\
# \text{MOM}_{30}^{(i)}\\
# \text{MACD}^{(i)}\\
# \text{PROC}_{9}^{(i)}\\
# \text{EMA}_{10}^{(i)}\\
# \text{EMA}_{30}^{(i)}\\
# \text{EMA}_{200}^{(i)}\\
# \%K_{10}^{(i)}\\
# \%K_{30}^{(i)}\\
# \%K_{200}^{(i)}\\
# \end{bmatrix},\quad\mathbf{x}^{(i)}\in\mathbb{R}^{n}$$
